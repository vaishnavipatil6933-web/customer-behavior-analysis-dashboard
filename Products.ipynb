# %%
import pandas as pd
products= pd.read_csv("E:/Users/vcvm2/Downloads/Airbnb+Data/Airbnb Data/Global+Electronics+Retailer/Products.csv", encoding='latin1')

# %%
products.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
products['Unit Cost USD'] = products['Unit Cost USD'].replace(r'[\$,]', '', regex=True).astype(float)
products['Unit Price USD'] = products['Unit Price USD'].replace(r'[\$,]', '', regex=True).astype(float)

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# 0

# %%
products['ProductKey'].nunique()
# Out:
# 2517

# %%
len(products)
# Out:
# 2517

# %%
products[products['Unit Price USD'] < products['Unit Cost USD']]
# Out:
# Empty DataFrame
# Columns: [ProductKey, Product Name, Brand, Color, Unit Cost USD, Unit Price USD, SubcategoryKey, Subcategory, CategoryKey, Category]
# Index: []

# %%
products['profit per unit'] = products['Unit Price USD'] - products['Unit Cost USD']

# %%
products['Category'].value_counts()
# Out:
# Category
# Home Appliances                  661
# Computers                        606
# Cameras and camcorders           372
# Cell phones                      285
# TV and Video                     222
# Games and Toys                   166
# Audio                            115
# Music, Movies and Audio Books     90
# Name: count, dtype: int64

# %%
products.columns = products.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
products.columns
# Out:
# Index(['productkey', 'product_name', 'brand', 'color', 'unit_cost_usd',
#        'unit_price_usd', 'subcategorykey', 'subcategory', 'categorykey',
#        'category', 'profit_per_unit'],
#       dtype='object')

# %%
products.to_excel("E:/Users/vcvm2/Downloads/Airbnb+Data/Airbnb Data/Global+Electronics+Retailer/cleaned_Product.xlsx", index=False)
