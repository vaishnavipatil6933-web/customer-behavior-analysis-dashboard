# %%
import pandas as pd 
exchange_rates = pd.read_csv("E:/Users/vcvm2/Downloads/Airbnb+Data/Airbnb Data/Global+Electronics+Retailer/Exchange_Rates.csv", encoding='latin1')

# %%
exchange_rates.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
exchange_rates['Date'] = pd.to_datetime(exchange_rates['Date'])

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
exchange_rates['Currency'] = exchange_rates['Currency'].str.upper().str.strip()

# %%
exchange_rates['Currency'] = exchange_rates['Currency'].str.upper().str.strip()

# %%
 exchange_rates= exchange_rates.sort_values(['Currency', 'Date'])

# %%
exchange_rates.rename(columns={
    'Currency': 'currency',
    'Exchange': 'exchange_rate'
}, inplace=True)

# %%
exchange_rates['currency'] = exchange_rates['currency'].str.upper().str.strip()
exchange_rates['exchange_rate'] = exchange_rates['exchange_rate'].astype(float)

# %%
exchange_rates.duplicated().sum()
# Out:
# 0

# %%
exchange_rates.isnull().sum()
# Out:
# Date             0
# currency         0
# exchange_rate    0
# dtype: int64

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11215 entries, 2 to 11210
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           11215 non-null  datetime64[ns]
#  1   currency       11215 non-null  object
#  2   exchange_rate  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 350.5+ KB

# %%
exchange_rates.to_excel("E:/Users/vcvm2/Downloads/Airbnb+Data/Airbnb Data/Global+Electronics+Retailer/cleaned_Exchange_rates.xlsx", index=False)
