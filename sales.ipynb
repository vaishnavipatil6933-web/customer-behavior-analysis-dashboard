# %%
import pandas as pd
sales = pd.read_csv("E:/Users/vcvm2/Downloads/Airbnb+Data/Airbnb Data/Global+Electronics+Retailer/Sales.csv", encoding='latin1')

# %%
sales.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
sales['order_date'] = pd.to_datetime(sales['Order Date'], errors='coerce')
sales['delivery_date'] = pd.to_datetime(sales['Delivery Date'], errors='coerce')

# %%
sales[['order_date', 'delivery_date']].dtypes
# Out:
# order_date       datetime64[ns]
# delivery_date    datetime64[ns]
# dtype: object

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# order_date           0
# delivery_date    49719
# dtype: int64

# %%
sales = sales.drop(columns=['Order Date', 'Delivery Date'])

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# order_date           0
# delivery_date    49719
# dtype: int64

# %%
sales['delivery_status'] = sales['delivery_date'].isnull().map({
    True: 'Not Delivered',
    False: 'Delivered'
})

# %%
sales['delivery_time'] = (sales['delivery_date'] - sales['order_date']).dt.days

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales[sales.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order Number, Line Item, CustomerKey, StoreKey, ProductKey, Quantity, Currency Code, order_date, delivery_date, delivery_status, delivery_time]
# Index: []

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales = sales.drop_duplicates()

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales.dtypes
# Out:
# Order Number                int64
# Line Item                   int64
# CustomerKey                 int64
# StoreKey                    int64
# ProductKey                  int64
# Quantity                    int64
# Currency Code              object
# order_date         datetime64[ns]
# delivery_date      datetime64[ns]
# delivery_status            object
# delivery_time             float64
# dtype: object

# %%
sales[sales['Quantity'] < 0]
# Out:
# Empty DataFrame
# Columns: [Order Number, Line Item, CustomerKey, StoreKey, ProductKey, Quantity, Currency Code, order_date, delivery_date, delivery_status, delivery_time]
# Index: []

# %%
sales[sales['Quantity'] < 0]
# Out:
# Empty DataFrame
# Columns: [Order Number, Line Item, CustomerKey, StoreKey, ProductKey, Quantity, Currency Code, order_date, delivery_date, delivery_status, delivery_time]
# Index: []

# %%
sales[['CustomerKey', 'ProductKey', 'Order Number']].isnull().sum()
# Out:
# CustomerKey     0
# ProductKey      0
# Order Number    0
# dtype: int64

# %%
sales[['Order Number', 'Line Item']].duplicated().sum()
# Out:
# 0

# %%
sales.columns = sales.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
sales.tail()
# Out:
#        order_number  line_item  customerkey  storekey  productkey  quantity  \
# 62879       2243030          1      1216913        43         632         3
# 62880       2243031          1       511229         0          98         4
# 62881       2243032          1       331277         0        1613         2
# 62882       2243032          2       331277         0        1717         2
# 62883       2243032          3       331277         0         464         7
#
#       currency_code order_date delivery_date delivery_status  delivery_time
# 62879           USD 2021-02-20           NaT   Not Delivered            NaN
# 62880           EUR 2021-02-20    2021-02-24       Delivered            4.0
# 62881           CAD 2021-02-20    2021-02-23       Delivered            3.0
# 62882           CAD 2021-02-20    2021-02-23       Delivered            3.0
# 62883           CAD 2021-02-20    2021-02-23       Delivered            3.0

# %%
sales.to_excel("E:/Users/vcvm2/Downloads/Airbnb+Data/Airbnb Data/Global+Electronics+Retailer/cleaned_Sales.xlsx", index=False)
